# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
url='https://movies.yahoo.com.tw/chart.html'

# %%
soup=BeautifulSoup(requests.get(url).text,'lxml')
soup
# Out:
# <!DOCTYPE html>
# <html lang="zh_TW">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, user-minimum-scale=1, maximum-scale=1" name="viewport"/>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="501887343352051" property="fb:app_id"/>
# <meta content="Yahoo奇摩電影戲劇" property="og:site_name"/>
# <link href="/favicon.ico?v=2" rel="icon"/>
# <link href="/build/css/pages/rank.css?id=b9cbce5f024a9c8e7ead8aa22ea55c11&amp;r=1673238185" rel="stylesheet"/>
# <link href="https://static.xx.fbcdn.net" rel="preconnect"/>
# <link href="https://www.facebook.com" rel="preconnect"/>
# <link as="font" crossorigin="" href="/build/fonts/fontawesome-webfont.woff2?v=4.7.0" rel="preload" type="font/woff2"/>
# <title>台北票房榜 - Yahoo奇摩電影戲劇</title>
# <meta content="台北票房榜 - Yahoo奇摩電影戲劇" name="twitter:title"/>
# <meta content="台北票房榜 - Yahoo奇摩電影戲劇" property="og:title"/>
# <link href="https://movies.yahoo.com.tw/chart.html" rel="canonical"/>
# <meta content="https://movies.yahoo.com.tw/chart.html" property="og:url"/>
# <meta content="Yahoo奇摩電影戲劇提供即將上映的最新電影、熱門戲劇影集資訊，查詢時刻表、看最新預告片，讓你電影、戲劇資訊不漏接" name="twitter:description"/>
# <meta content="Yahoo奇摩電影戲劇提供即將上映的最新電影、熱門戲劇影集資訊，查詢時刻表、看最新預告片，讓你電影、戲劇資訊不漏接" name="description"/>
# <meta content="Yahoo奇摩電影戲劇提供即將上映的最新電影、熱門戲劇影集資訊，查詢時刻表、看最新預告片，讓你電影、戲劇資訊不漏接" property="og:description"/>
# <meta content="https://movies.yahoo.com.tw/build/images/ogImage.png?r=1673238185" name="twitter:image"/>
# <meta content="https://movies.yahoo.com.tw/build/images/ogImage.png?r=1673238185" property="og:image"/>
# <meta content="https://movies.yahoo.com.tw/build/images/ogImage.png?r=1673238185" name="twitter:image:src"/>
# <meta content="電影,院線電影,線上戲劇,線上電影,影劇, yahoo奇摩電影戲劇, 時刻表, 新片, 預告片, 網友滿意榜, yahoo 電影, 劇照, 線上訂票, 票房, 台北票房, 全美票房, 排行榜, 戲院, 片名, 電視, 熱映中, 本週新片, 海報, 滿意度, 期待度" name="keywords"/>
# <link href="/build/css/pages/main-layout.css?id=6ef5027c56295df377ac1095bdccaa37&amp;r=1673238185" rel="stylesheet"/>
# <meta content="guce.yahoo.com.tw" name="oath:guce:consent-host"/>
# <!-- Consent Manager Tag : Script -->
# <script async="" src="https://consent.cmp.oath.com/cmp.js" type="text/javascript"></script>
# <!-- Consent Manager Tag : Stubbed (updated 2018-04-27T17:00) -->
# <script type="text/javascript">
#     (function () {
#         var gdprAppliesGlobally = false;
#
#         function addFrame() {
#             if (!window.frames['__cmpLocator']) {
#                 if (document.body && document.body.firstChild) {
#                     var body = document.body,
#                         iframe = document.createElement('iframe');
#
#                       iframe.style.display = 'none';
# 			  iframe.height = iframe.width = 0;
#
#                     iframe.name = '__cmpLocator';
#                     body.insertBefore(iframe, body.firstChild);
#                 } else {
#                     setTimeout(addFrame, 5);
#                 }
#             }
#         }
#
#         addFrame();
#
#         function stubCMP() {
#             var b = arguments;
#             __cmp.a = __cmp.a || [];
#
#             if (!b.length) return __cmp.a;
#             else if (b[0] === 'ping') {
#                 b[2]({
#                     "gdprAppliesGlobally": gdprAppliesGlobally,
#                     "cmpLoaded": false
#                 }, true);
#             }
#             else {
#                 __cmp.a.push([].slice.apply(b));
#             }
#         }
#
#         function cmpMsgHandler(event) {
#             var msgIsString = typeof event.data === "string";
#             var json = event.data;
#             if (msgIsString) {
#                 try {
#                     json = JSON.parse(event.data);
#                 } catch (e) {}
#             }
#             if (json.__cmpCall) {
#                 var i = json.__cmpCall;
#                 window.__cmp(i.command, i.parameter, function (retValue, success) {
#                     var returnMsg = {
#                         "__cmpReturn": {
#                             "returnValue": retValue,
#                             "success": success,
#                             "callId": i.callId
#                         }
#                     };
#                     event.source.postMessage(msgIsString ?
#                         JSON.stringify(returnMsg) : returnMsg, '*');
#                 });
#             }
#         }
#
#         if (typeof (__cmp) !== 'function') {
#             window.__cmp = stubCMP;
#             __cmp.msgHandler = cmpMsgHandler;
#             if (window.addEventListener)
#                 window.addEventListener('message', cmpMsgHandler, false);
#             else window.attachEvent('onmessage', cmpMsgHandler);
#         }
#     })();
#
# </script>
# <!-- End Consent Manager Tag : Stubbed -->
# <script type="text/javascript">
#     window.__cmp('init');
# </script>
# <script defer="" src="https://s.yimg.com/nb/AdLib/adlib-prod.umd.min.js" type="text/javascript"></script> <script>
#
#     var DARLA_CONFIG = {
#         "positions": {
#             // for ad hashtag cny issue, LREC using script to load
#             // "LREC" : {
#             //     id: "LREC",
#             //     name: "LREC",
#             //     clean: "boxLREC",
#             //     dest: "tgtLREC",
#             //     w: 300,
#             //     h: 250,
#             //     //async: true,
#             //     metaSize: true
#             // },
#             "LREC2" : {
#                 id: "LREC2",
#                 name: "LREC2",
#                 clean: "boxLREC2",
#                 dest: "tgtLREC2",
#                 w: 300,
#                 h: 250,
#                 //async: true,
#                 metaSize: true
#             },
#             "LREC3" : {
#                 id: "LREC3",
#                 name: "LREC3",
#                 clean: "boxLREC3",
#                 dest: "tgtLREC3",
#                 w: 300,
#                 h: 250,
#                 //async: true,
#                 metaSize: true
#             },
#             "LDRB" : {
#                 id: "LDRB",
#                 name: "LDRB",
#                 clean: "boxLDRB",
#                 dest: "tgtLDRB",
#                 w: 728,
#                 h: 90,
#                 //async: true,
#                 metaSize: true
#             },
#             "NP1" : {
#                 id: "NP1",
#                 name: "NP1",
#                 clean: "boxNP1",
#                 dest: "tgtNP1",
#                 w: 300,
#                 h: 100,
#                 async: true,
#                 metaSize: true
#             },
#             //original config
#             // "MAST" : {
#             //     id: "MAST",
#             //     name: "MAST",
#             //     clean: "boxMAST",
#             //     dest: "tgtMAST",
#             //     w: 970,
#             //     h: 250,
#             //     async: true,
#             //     metaSize: true
#             // },
#             //from sports fp
#             "MAST":{
#                 id:"MAST",
#                 name:"MAST", //add
#                 w:970,
#                 h:250,
#                 //async:true, //add
#                 autoFetch:false,
#                 fr:"expIfr_exp",
#                 supports:{
#                     "exp-ovr":1,
#                     "exp-push":1,
#                     "resize-to":1
#                 },
#                 enable:true,
#                 staticLayou:false,
#                 fdb:false,
#                 closeBtn:{
#                     "mode":2,
#                     "useShow":1,
#                     "adc":0
#                 },
#                 metaSize:true,
#                 clean:"boxMAST",
#                 dest:"tgtMAST",
#                 fallback:null,
#                 failed:false
#             },
# 	    	"DEFAULT": {
# 		    	supports: {
# 			    	"bg": 1,
# 				    "exp-ovr": 1,
# 				    "exp-push": 0,
# 				    "lyr": 0,
# 				    "cmsg":1
# 			    }
# 		    }
#         }, events: {
# 		        reloadLREC: {
# 		            ps: 'LREC',
# 		            sp: '794026727'
# 		        },
# 		        reloadNP1: {
# 		            ps: 'NP1',
# 		            sp: '794026727'
# 		        },
# 		        reloadLREC2: {
# 		            ps: 'LREC2',
# 		            sp: '794026727'
# 		        },
# 		        reloadLREC3: {
# 		            ps: 'LREC3',
# 		            sp: '794026727'
# 		        },
# 		    }
#     };
#     // function getCurrentAdsKeys () {
#     //     return Object.keys(window.DARLA_CONFIG.positions).filter(
#     //         function(v) {
#     //             console.log(document.getElementById('box' + v));
#     //             return v !='DEFAULT'
#     //         });
#     // }
#
#     // console.log(getCurrentAdsKeys());
#
#     // DARLA_CONFIG.onFailure = function (e) {
#     //     console.log('DARLA_CONFIG onFailure');
#     // };
#     // DARLA_CONFIG.onTimeout = function (e) {
#     //     console.log('DARLA_CONFIG onTimeout');
#     // };
#     DARLA_CONFIG.onSuccess = function (e, y) {
#         const ads =  Object.keys(DARLA_CONFIG.positions);
#         ads.forEach(ad => {
#             if(!a.includes(ad)) {
#                 const element = document.querySelector(`#box${ad}`);
#                 if(element) {
#                     console.log(`ad ${ad} load failed, set height to 0`);
#                     element.style.height = 0;
#                 }
#             }
#         });
#         // console.log('DARLA_CONFIG onSuccess ');
#         // console.log(y);
#     };
#     // DARLA_CONFIG.onRenderTimeout = function (e) {
#     //     console.log('DARLA_CONFIG onRenderTimeout ');
#     // };
#     // DARLA_CONFIG.onRequestTimeout = function (e) {
#     //     console.log('DARLA_CONFIG onRequestTimeout ');
#     // };
#     // DARLA_CONFIG.onBeforeStartRequest = function (e) {
#     //     console.log('DARLA_CONFIG onBeforeStartRequest');
#     // };
#     // DARLA_CONFIG.onFinishRequest = function (e) {
#     //     console.log('DARLA_CONFIG onFinishRequest');
#     // };
#     // DARLA_CONFIG.onStartParse = function (e) {
#     //     console.log('DARLA_CONFIG onStartParse');
#     // };
#     // DARLA_CONFIG.onPreParse = function (e) {
#     //     console.log('DARLA_CONFIG onPreParse');
#     // };
#     // DARLA_CONFIG.onStartPosRender = function (e) {
#     //     console.log('DARLA_CONFIG onStartPosRender ');
#     //     console.log(e);
#     // };
#     // DARLA_CONFIG.onFinishPosRender = function (posId, reqList, posItem) {
#     //     console.log('DARLA_CONFIG onFinishPosRender');
#     //     console.log(posId);
#     //     console.log(reqList);
#     //     console.log(posItem);
#     // };
#     // DARLA_CONFIG.onBeforePosMsg = function (e) {
#     //     console.log('DARLA_CONFIG onBeforePosMsg');
#     // };
#     // DARLA_CONFIG.onFinishParse = function (e) {
#     //     console.log('DARLA_CONFIG onFinishParse');
#     // };
#     // DARLA_CONFIG.onStartPrefetchRequest = function (e) {
#     //     console.log('DARLA_CONFIG onStartPrefetchRequest');
#     // };
#     // DARLA_CONFIG.onFinishPrefetchRequest = function (e) {
#     //     console.log('DARLA_CONFIG onFinishPrefetchRequest');
#     // };
#  </script>
# <script src="https://fc.yahoo.com/sdarla/php/client.php?f=794026727&amp;debug=1&amp;l=MAST{dest:tgtMAST,azn:970x250},LREC2{dest:tgtLREC2,azn:300x250},LREC3{dest:tgtLREC3,azn:300x250},NP1{dest:tgtNP1,azn:300x100},LDRB{dest:tgtLDRB,azn:728x90}&amp;npv=1&amp;"></script>
# </head>
# <body id="">
# <div id="ranks"></div>
# <data data-login="false" data-login-href="https://movies.yahoo.com.tw/login"></data>
# <span data-pt="minihome" data-spaceid="794026727" id="tracking-data"></span>
# <!--Website-->
# <div id="maincontainer">
# <header class="header">
# <div id="y-header">
# <nav class="nav content">
# <ul>
# <li><a class="gabtn" data-ga="['頻道入口','頻道入口_Yahoo首頁','頁首_頻道入口']" href="https://tw.yahoo.com/"><span class="icon_home"></span>首頁</a></li>
# <li><a class="gabtn" data-ga="['頻道入口','頻道入口_信箱','頁首_頻道入口']" href="https://tw.mail.yahoo.com/">信箱</a></li>
# <li><a class="gabtn" data-ga="['頻道入口','頻道入口_新聞','頁首_頻道入口']" href="https://tw.news.yahoo.com/">新聞</a></li>
# <li><a class="gabtn" data-ga="['頻道入口','頻道入口_股市','頁首_頻道入口']" href="https://tw.stock.yahoo.com/">股市</a></li>
# <li><a class="gabtn" data-ga="['頻道入口','頻道入口_氣象','頁首_頻道入口']" href="https://tw.news.yahoo.com/weather-forecast/">氣象</a></li>
# <li><a class="gabtn" data-ga="['頻道入口','頻道入口_運動','頁首_頻道入口']" href="https://tw.sports.yahoo.com/">運動</a></li>
# <li><a class="gabtn" data-ga="['頻道入口','頻道入口_名人娛樂','頁首_頻道入口']" href="https://tw.news.yahoo.com/entertainment">名人娛樂</a></li>
# <li><a class="gabtn" data-ga="['頻道入口','頻道入口_App下載','頁首_頻道入口']" href="http://tw.mobile.yahoo.com/">App下載</a></li>
# <li><a class="gabtn" data-ga="['頻道入口','頻道入口_購物中心','頁首_頻道入口']" href="https://tw.buy.yahoo.com/">購物中心</a></li>
# <li><a class="gabtn" data-ga="['頻道入口','頻道入口_商域','頁首_頻道入口']" href="https://tw.mall.yahoo.com/">商城</a></li>
# <li><a class="gabtn" data-ga="['頻道入口','頻道入口_拍賣','頁首_頻道入口']" href="https://tw.bid.yahoo.com/">拍賣</a></li>
# <li class="nav_more">
# <a href="javascript:void(0)">更多<span class="icon_more"></span></a>
# <div class="dropdown_list">
# <dl>
# <dd><a class="gabtn" data-ga="['頻道入口','頻道入口_影音','頁首_頻道入口']" href="https://tw.video.yahoo.com/">影音</a></dd>
# <dd><a class="gabtn" data-ga="['頻道入口','頻道入口_汽車機車','頁首_頻道入口']" href="https://autos.yahoo.com.tw/">汽車機車</a></dd>
# <dd><a class="gabtn" data-ga="['頻道入口','頻道入口_電影','頁首_頻道入口']" href="https://movies.yahoo.com.tw/">電影戲劇</a></dd>
# <dd><a class="gabtn" data-ga="['頻道入口','頻道入口_字典','頁首_頻道入口']" href="https://tw.dictionary.yahoo.com/">字典</a></dd>
# <dd><a class="gabtn" data-ga="['頻道入口','頻道入口_遊戲','頁首_頻道入口']" href="https://games.yahoo.com.tw/">遊戲</a></dd>
# <dd><a class="gabtn" data-ga="['頻道入口','頻道入口_旅遊','頁首_頻道入口']" href="https://travel.yahoo.com.tw/">旅遊</a></dd>
# <dd><a class="gabtn" data-ga="['頻道入口','頻道入口_理財','頁首_頻道入口']" href="https://tw.money.yahoo.com/">理財</a></dd>
# <dd><a class="gabtn" data-ga="['頻道入口','頻道入口_房地產','頁首_頻道入口']" href="https://house.yahoo.com.tw/">房地產</a></dd>
# <dd><a class="gabtn" data-ga="['頻道入口','頻道入口_時尚美妝','頁首_頻道入口']" href="https://style.yahoo.com.tw/">時尚美妝</a></dd>
# <dd><a class="gabtn" data-ga="['頻道入口','頻道入口_折扣城','頁首_頻道入口']" href="https://tw.discount.yahoo.net/index.php?group=all">折扣城</a></dd>
# </dl>
# </div>
# </li>
# </ul>
# </nav>
# </div>
# <div id="kv">
# <div class="content">
# <div class="_c" id="y_hous_serch">
# <div id="y_serch_l">
# <a class="gabtn" data-ga="['電影頻道logo','電影頻道logo_連結','頁首_電影頻道logo']" href="https://movies.yahoo.com.tw/index.html" id="ylogo">
# <img alt="Yahoo Logo" src="/build/images/header_logo.png?r=1673238185" srcset="/build/images/header_logo@2x.png?r=1673238185 2x, /build/images/header_logo@3x.png?r=1673238185 3x"/>
# </a>
# <form action="https://tw.search.yahoo.com/search" method="get" target="_blank">
# <input autocomplete="off" id="serchinput" name="p" placeholder="搜尋" type="text"/>
# <div class="inputex" style="visibility:hidden"></div>
# <button class="serch_movie gabtn" data-ga="['top search','top search_電影明星搜尋','']" data-input="['input','serchinput','']">影劇、明星搜尋</button><!--20170531-->
# <button class="gabtn" data-ga="['top search','top search_網頁搜尋','']" data-input="['input','serchinput','']" type="submit">網頁搜尋</button><!--20170531-->
# <input id="fr" name="fr" type="hidden" value="ush-movies"/>
# </form>
# </div>
# </div>
# </div>
# </div>
# <!-- jurisdiction-type: WORLD -->
# <div id="bg_main_menu">
# <div class="content">
# <ul id="mainmenu">
# <li class="">
# <a class="gabtn" data-ga="['選單','選單_首頁','頁首_選單']" href="https://movies.yahoo.com.tw" target="">
# <span>首頁</span>
# </a>
# </li>
# <li class="">
# <a class="gabtn" data-ga="['選單','選單_本週新片','頁首_選單']" href="https://movies.yahoo.com.tw/movie_thisweek.html" target="">
# <span>本週新片</span>
# </a>
# </li>
# <li class="">
# <a class="gabtn" data-ga="['選單','選單_上映中','頁首_選單']" href="https://movies.yahoo.com.tw/movie_intheaters.html" target="">
# <span>上映中</span>
# </a>
# </li>
# <li class="">
# <a class="gabtn" data-ga="['選單','選單_即將上映','頁首_選單']" href="https://movies.yahoo.com.tw/movie_comingsoon.html" target="">
# <span>即將上映</span>
# </a>
# </li>
# <li class="">
# <a class="gabtn" data-ga="['選單','選單_預告片','頁首_選單']" href="https://movies.yahoo.com.tw/trailer_index.html" target="">
# <span>預告片</span>
# </a>
# </li>
# <li class="select">
# <a class="gabtn" data-ga="['選單','選單_排行榜','頁首_選單']" href="https://movies.yahoo.com.tw/chart.html" target="">
# <span>排行榜</span>
# </a>
# </li>
# <li class="hassub">
# <a class="gabtn" data-ga="['選單','選單_情報站','頁首_選單']" href="https://movies.yahoo.com.tw/article_index.html" target="">
# <span>情報站</span>
# </a>
# <div class="submenu">
# <dl class="submenu_inner">
# <dt>
# <a class="gabtn" data-ga="['選單','選單_情報站_電影新聞','頁首_選單']" href="https://movies.yahoo.com.tw/tagged/movieheadline" target="">
#                         電影新聞
#                       </a>
# </dt>
# <dt>
# <a class="gabtn" data-ga="['選單','選單_情報站_專題報導','頁首_選單']" href="https://movies.yahoo.com.tw/tagged/spotlight" target="">
#                         專題報導
#                       </a>
# </dt>
# <dt>
# <a class="gabtn" data-ga="['選單','選單_情報站_影評','頁首_選單']" href="https://movies.yahoo.com.tw/tagged/moviereview" target="">
#                         影評
#                       </a>
# </dt>
# </dl>
# </div>
# </li>
# <li class="">
# <a class="gabtn" data-ga="['選單','選單_電視時刻','頁首_選單']" href="https://movies.yahoo.com.tw/tv_index.html" target="">
# <span>電視時刻</span>
# </a>
# </li>
# <li class="hassub">
# <a class="gabtn" data-ga="['選單','選單_追劇','頁首_選單']" href="https://movies.yahoo.com.tw/ott_index.html" target="">
# <span>追劇</span>
# </a>
# <div class="submenu">
# <dl class="submenu_inner">
# <dt>
# <a class="gabtn" data-ga="['選單','選單_追劇_追劇情報','頁首_選單']" href="https://movies.yahoo.com.tw/tagged/ottdrama" target="">
#                         追劇情報
#                       </a>
# </dt>
# <dt>
# <a class="gabtn" data-ga="['選單','選單_追劇_線上電影情報','頁首_選單']" href="https://movies.yahoo.com.tw/tagged/ottmovie" target="">
#                         線上電影情報
#                       </a>
# </dt>
# <dt>
# <a class="gabtn" data-ga="['選單','選單_追劇_最新線上影劇','頁首_選單']" href="https://movies.yahoo.com.tw/ott_drama.html" target="">
#                         最新線上影劇
#                       </a>
# </dt>
# <dt>
# <a class="gabtn" data-ga="['選單','選單_追劇_影劇檢索','頁首_選單']" href="https://movies.yahoo.com.tw/category.html" target="">
#                         影劇檢索
#                       </a>
# </dt>
# <dt>
# <a class="gabtn" data-ga="['選單','選單_追劇_戲劇排行榜','頁首_選單']" href="https://movies.yahoo.com.tw/tagged/drama-ranking" target="">
#                         戲劇排行榜
#                       </a>
# </dt>
# </dl>
# </div>
# </li>
# </ul>
# </div>
# </div>
# </header>
# <!--主內容-->
# <main>
# <!--top_ad-->
# <div class="maincontent">
# <div class="boxAD" id="boxMAST">
# <div class="adpos" id="tgtMAST"></div>
# </div>
# <div class="content _c" id="top_serch">
# <div data-topserch="0">
# <div class="tab_serch _c">
# <div class="tab_hot">
# <a class="gabtn" data-ga="['search box','search box_熱門1','黑暗榮耀']" href="https://movies.yahoo.com.tw/movieinfo_main/黑暗榮耀-the-glory-14459" target="">黑暗榮耀</a>
# <a class="gabtn" data-ga="['search box','search box_熱門2','電影粉絲團']" href="https://www.facebook.com/YahooTW.Movies" target="">電影粉絲團</a>
# <a class="gabtn" data-ga="['search box','search box_熱門3','追劇報報']" href="https://movies.yahoo.com.tw/weekly-drama-145813216.html" target="">追劇報報</a>
# </div>
# <a class="btn_booking btn_toptxt gabtn" data-ga="['search box','search box_訂票客服中心','']" href="https://www.ezding.com.tw/page/faq/faq.html" target="_blank">訂票客服中心</a>
# <a class="btn_all btn_toptxt gabtn" data-ga="['search box','search box_戲院總覽','']" href="https://movies.yahoo.com.tw/theater_list.html">戲院總覽</a>
# <div class="btn_index_search">
# <i aria-hidden="true" class="fa fa-file-text-o"></i>
# <a class="btn_toptxt gabtn" data-ga="['search box','search box_戲院總覽','']" href="https://movies.yahoo.com.tw/category.html">影劇檢索</a>
# </div>
# </div>
# <span data-url="https://movies.yahoo.com.tw" id="mainURL"></span>
# <span data-type="0" id="searchType"></span>
# <div class="tab_serchbar">
# <div class="icon_serch"></div>
# <select id="movie_time" name="search_type">
# <option value="0">電影時刻</option>
# <option value="1">電視時刻</option>
# <option value="2">快速訂票</option>
# <option value="3">電影/影劇/明星搜尋</option>
# </select>
# <!--tab_serchbar  style0-->
# <div class="top_change" data-change="0" style="">
# <form action="https://movies.yahoo.com.tw/movietime_result.html" id="form_moviearea" method="get">
# <span>選擇<br/>片名</span>
# <select class="movie_name" data-loaded="false" data-url="https://movies.yahoo.com.tw/ajax/in_theater_movies" id="sbox_mid" name="movie_id">
# <option value="">請選擇片名</option>
# </select>
# <span>選擇<br/>地區</span>
# <select class="movie_area" id="sbox_aid" name="area_id">
# </select>
# <div class="btn_serch gabtn" data-ga="['search box','search box_電影時刻','']" data-input="['select','sbox_mid','sbox_aid']">查詢</div>
# </form>
# </div>
# <!--tab_serchbar  style1-->
# <div class="top_change" data-change="1" style="display:none;">
# <form action="https://movies.yahoo.com.tw/tv_channels.html" id="form_catechannel" method="get" style="display:inline;">
# <span>選擇<br/>分類</span>
# <select class="movie_theater" id="sbox_cid" name="tv_category_id">
# <option value="">請選擇分類</option>
# <option data-name="西片" value="1">西片</option>
# <option data-name="國片" value="2">國片</option>
# <option data-name="戲劇" value="3">戲劇</option>
# <option data-name="體育" value="4">體育</option>
# <option data-name="綜合" value="5">綜合</option>
# <option data-name="知性" value="6">知性</option>
# <option data-name="日本" value="7">日本</option>
# <option data-name="音樂" value="8">音樂</option>
# <option data-name="卡通" value="9">卡通</option>
# <option data-name="新聞" value="10">新聞</option>
# <option data-name="財經" value="11">財經</option>
# <option data-name="宗教" value="12">宗教</option>
# </select>
# <span>選擇<br/>頻道</span>
# <select class="movie_name" id="sbox_chid" name="channel">
# </select>
# <div class="btn_serch gabtn" data-ga="['search box','search box_電視時刻','']" data-input="['select','sbox_cid','sbox_chid']">查詢</div>
# </form>
# <form action="https://movies.yahoo.com.tw/tvtime_result.html" id="form_channelname" method="get" style="display:inline;">
# <input autocomplete="off" class="tvserch" id="sbox_cname" name="tv_channel_name" onblur="this.placeholder='電視節目查詢'" onfocus="this.placeholder=''" onkeypress="chlSearchForm(event);" placeholder="電視節目查詢" type="text"/>
# <div class="btn_serch gabtn" data-ga="['search box','search box_電視節目查詢','']" data-input="['input','sbox_cname','']">查詢</div>
# </form>
# </div>
# <!--tab_serchbar  style2-->
# <div class="top_change" data-change="2" style="display:none;">
# <form action="https://www.ezding.com.tw/page/booking/index.html?channel=yahoo&amp;campaign_code=yahoopc" id="form_movieticket" method="get">
# <span>選擇<br/>戲院</span>
# <select class="movie_theater" data-loaded="false" data-url="https://movies.yahoo.com.tw/ajax/cinemas" id="sbox_tid" name="cinemaId">
# <option value="">請選擇戲院</option>
# </select>
# <span>選擇<br/>片名</span>
# <select class="movie_name" id="sbox_tmid" name="movieId">
# </select>
# <span>選擇<br/>日期</span>
# <select class="movie_day" name="showDate">
# </select>
# <span>選擇<br/>場次</span>
# <select class="movie_screenings" name="session">
# </select>
# <span>選擇<br/>數量</span>
# <select class="movie_amount" name="ticketQuantity">
# </select>
# <div class="btn_serch gabtn" data-ga="['search box','search box_快速訂票','']" data-input="['select','sbox_tid','sbox_tmid']">查詢</div>
# </form>
# </div>
# <!--tab_serchbar  style3-->
# <div class="top_change" data-change="3" style="display:none;">
# <form action="https://movies.yahoo.com.tw/moviesearch_result.html" id="form_starsearch" method="get">
# <select name="movie_type">
# <option value="all">全部</option>
# <option value="movie">院線電影</option>
# <option value="drama">戲劇影集</option>
# <option value="online_movie">線上電影</option>
# </select>
# <input autocomplete="off" class="starserch" id="starserch" name="keyword" onblur="this.placeholder='電影/ 明星搜尋'" onfocus="this.placeholder=''" placeholder="電影 / 明星搜尋" type="text"/>
# <div class="inputex" style="visibility:hidden">
# </div>
# <div class="btn_serch gabtn" data-ga="['search box','search box_電影明星搜尋','']" data-input="['input','starserch','']">查詢</div>
# </form>
# </div>
# </div>
# </div>
# </div>
# <div class="content _c" id="container">
# <div id="content_r">
# <div class="ad_300_250 r_box" data-ad="LREC" id="boxLREC">
# <!-- Using script loaded for cny hashtag issue -->
# <script language="JavaScript" src="https://global.adserver.yahoo.com/a?f=794026727&amp;p=tw_kimo&amp;l=LREC&amp;c=r" type="text/javascript"></script>
# <noscript>
# <iframe frameborder="0" height="250" hspace="0" marginheight="0" marginwidth="0" scrolling="no" src="https://global.adserver.yahoo.com/a?f=794026727&amp;p=tw_kimo&amp;l=LREC&amp;c=sr&amp;bg=white" vspace="0" width="300"></iframe>
# </noscript>
# </div>
# <!--AD 300X100-->
# <div class="ad_300_100 r_box" data-ad="NP1" id="boxNP1">
# <div class="adpos" id="tgtNP1"></div>
# </div>
# <!--電影排行榜-->
# <div class="r_box _c">
# <div class="title">
# <span>
#             電影排行榜
#         </span>
# </div>
# <div class="r_box_inner">
# <ul class="tabbox_btn_r">
# <li class="select" data-id="list1">台北票房榜</li>
# <li data-id="list2" data-loaded="false" data-type="us" data-url="https://movies.yahoo.com.tw/ajax/movie_rank_tab">全美票房榜</li>
# <li data-id="list3" data-loaded="false" data-type="popular" data-url="https://movies.yahoo.com.tw/ajax/movie_rank_tab">預告片榜</li>
# </ul>
# <div class="ranking_inner_r">
# <div class="tab-content">
# <div class="tab-pane" id="list1">
# <div class="ranking_top_info_r _c">
# <div class="ranking_top_info_img_r">
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_台北票房榜','灌籃高手 THE FIRST SLAM DUNK']" href="https://movies.yahoo.com.tw/movieinfo_main/%E7%81%8C%E7%B1%83%E9%AB%98%E6%89%8B-THE-FIRST-SLAM-DUNK-the-first-slam-dunk-14330">
# <img alt="" src="https://movies.yahoo.com.tw/i/r/w420/production/movies/November2022/Ehl7e402ukfrGS1Ih7Mh-1080x1542.jpg"/>
# </a>
# </div>
# <div class="ranking_top_info_inner_r">
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_台北票房榜','灌籃高手 THE FIRST SLAM DUNK']" href="https://movies.yahoo.com.tw/movieinfo_main/%E7%81%8C%E7%B1%83%E9%AB%98%E6%89%8B-THE-FIRST-SLAM-DUNK-the-first-slam-dunk-14330">
#                 灌籃高手 THE FIRST SLAM DUNK
#             </a>
# <span class="text_truncate_4 text_truncate_dot">「教練，我想打籃球！」火紅32年的經典漫畫《灌籃高手》從1990年連載到1996年，人物角色為了籃球比賽揮灑熱血汗水激勵不少人骨子裡的「籃球魂」，光在日本的發行量就超過1億2千萬冊，在台灣也擄獲不少粉絲，櫻木花道、流川楓、宮城良田、三井壽、赤木剛憲、赤木晴子等角色都各自有擁護者；儘管連載結束26年，書迷一直引頸期盼作品能回歸，2019年當原作井上雄彥在社群公佈櫻木花道的繪圖時，關注度瞬間破表，大家紛紛留言回憶起當年追漫畫跟動畫的感動，就知道書迷有多期待。</span>
# </div>
# </div>
# <ul class="ranking_list_r">
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_台北票房榜','灌籃高手 THE FIRST SLAM DUNK']" href="https://movies.yahoo.com.tw/movieinfo_main/%E7%81%8C%E7%B1%83%E9%AB%98%E6%89%8B-THE-FIRST-SLAM-DUNK-the-first-slam-dunk-14330">
# <li class="select">
# <div class="num">1</div>
# <span>灌籃高手 THE FIRST SLAM DUNK</span>
# </li>
# </a>
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_台北票房榜','阿凡達：水之道']" href="https://movies.yahoo.com.tw/movieinfo_main/%E9%98%BF%E5%87%A1%E9%81%94-%E6%B0%B4%E4%B9%8B%E9%81%93-avatar-the-way-of-water-13257">
# <li class="">
# <div class="num">2</div>
# <span>阿凡達：水之道</span>
# </li>
# </a>
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_台北票房榜','窒友梅根']" href="https://movies.yahoo.com.tw/movieinfo_main/%E7%AA%92%E5%8F%8B%E6%A2%85%E6%A0%B9-m3gan-14169">
# <li class="">
# <div class="num">3</div>
# <span>窒友梅根</span>
# </li>
# </a>
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_台北票房榜','想見你']" href="https://movies.yahoo.com.tw/movieinfo_main/%E6%83%B3%E8%A6%8B%E4%BD%A0-someday-or-one-day-14528">
# <li class="">
# <div class="num">4</div>
# <span>想見你</span>
# </li>
# </a>
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_台北票房榜','我的婆婆怎麼把OO搞丟了']" href="https://movies.yahoo.com.tw/movieinfo_main/%E6%88%91%E7%9A%84%E5%A9%86%E5%A9%86%E6%80%8E%E9%BA%BC%E6%8A%8AOO%E6%90%9E%E4%B8%9F%E4%BA%86-u-motherbaker-the-movie-14317">
# <li class="">
# <div class="num">5</div>
# <span>我的婆婆怎麼把OO搞丟了</span>
# </li>
# </a>
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_台北票房榜','在我和天空之間']" href="https://movies.yahoo.com.tw/movieinfo_main/%E5%9C%A8%E6%88%91%E5%92%8C%E5%A4%A9%E7%A9%BA%E4%B9%8B%E9%96%93-living-in-your-sky-13601">
# <li class="">
# <div class="num">6</div>
# <span>在我和天空之間</span>
# </li>
# </a>
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_台北票房榜','鞋貓劍客2']" href="https://movies.yahoo.com.tw/movieinfo_main/%E9%9E%8B%E8%B2%93%E5%8A%8D%E5%AE%A22-puss-in-boots-the-last-wish-12816">
# <li class="">
# <div class="num">7</div>
# <span>鞋貓劍客2</span>
# </li>
# </a>
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_台北票房榜','輝夜姬想讓人告白-永不結束的初吻']" href="https://movies.yahoo.com.tw/movieinfo_main/%E8%BC%9D%E5%A4%9C%E5%A7%AC%E6%83%B3%E8%AE%93%E4%BA%BA%E5%91%8A%E7%99%BD-%E6%B0%B8%E4%B8%8D%E7%B5%90%E6%9D%9F%E7%9A%84%E5%88%9D%E5%90%BB-kaguya-sama-love-is-war-the-first-kiss-that-never-ends-14542">
# <li class="">
# <div class="num">8</div>
# <span>輝夜姬想讓人告白-永不結束的初吻</span>
# </li>
# </a>
# <li class="unclick">
# <div class="num">9</div>
# <span>巧虎電影　巧虎與塔魯王子</span>
# </li>
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_台北票房榜','愛．子']" href="https://movies.yahoo.com.tw/movieinfo_main/%E6%84%9B-%E5%AD%90-the-son-14054">
# <li class="">
# <div class="num">10</div>
# <span>愛．子</span>
# </li>
# </a>
# </ul>
# <div class="rankin_time_r">統計時間 : 2023-01-14~2023-01-15</div>
# </div>
# <div class="tab-pane" id="list2"></div>
# <div class="tab-pane" id="list3"></div>
# </div>
# <div class="btn_plus_more gabtn rk" data-ga="['電影排行榜','電影排行榜_台北票房榜_看更多','']">
# <a href="https://movies.yahoo.com.tw/chart.html">
# <div class="plus"></div>看更多
#         </a>
# </div>
# <div class="btn_plus_more gabtn rk" data-ga="['電影排行榜','電影排行榜_全美票房榜_看更多','']">
# <a href="https://movies.yahoo.com.tw/chart.html?cate=us">
# <div class="plus"></div>看更多
#         </a>
# </div>
# <div class="btn_plus_more gabtn rk" data-ga="['電影排行榜','電影排行榜_預告片榜_看更多','']">
# <a href="https://movies.yahoo.com.tw/chart.html?cate=trailer">
# <div class="plus"></div>看更多
#         </a>
# </div>
# </div>
# </div>
# </div>
# <!--AD 300X156-->
# <div class="native-ad-right">
# </div>
# <!--AD 300X250-->
# <div class="ad_300_250 r_box" data-ad="LREC3" id="boxLREC3">
# <div class="adpos" id="tgtLREC3"></div>
# </div>
# <!--FB-->
# <div class="fb r_box">
# <div class="fb-page fb-position-fixed" data-adapt-container-width="true" data-height="500" data-hide-cover="false" data-href="https://www.facebook.com/YahooTW.Movies" data-lazy="true" data-show-facepile="false" data-small-header="false" data-tabs="timeline" data-width="300"><blockquote cite="https://www.facebook.com/YahooTW.Movies/" class="fb-xfbml-parse-ignore"><a href="https://www.facebook.com/YahooTW.Movies/">Yahoo奇摩電影戲劇</a></blockquote></div>
# </div>
# <!--AD 300X250-->
# <div class="ad_300_250 r_box" data-ad="LREC2" id="boxLREC2">
# <div class="adpos" id="tgtLREC2"></div>
# </div>
# <!--你最近瀏覽的電影-->
# <div class="r_box _c">
# <div class="title">
# <span>
#             你最近瀏覽的電影
#         </span>
# </div>
# <div class="r_box_inner">
# <ul class="recently_viewed">
# </ul>
# </div>
# </div>
# <div></div>
# </div>
# <div id="content_l">
# <div id="content_l">
# <!--電影資訊-->
# <div class="l_box">
# <div class="movie_tab">
# <ul class="movie_tab_list split">
# <li class="select">
# <a class="gabtn" data-ga="['排行榜','排行榜_台北票房榜tab','']" href="https://movies.yahoo.com.tw/chart.html">台北票房榜</a>
# </li>
# <li>
# <a class="gabtn" data-ga="['排行榜','排行榜_全美票房榜tab','']" href="https://movies.yahoo.com.tw/chart.html?cate=us">全美票房榜</a>
# </li>
# <li>
# <a class="gabtn" data-ga="['排行榜','排行榜_週冠軍票房列表tab','']" href="https://movies.yahoo.com.tw/chart.html?cate=week">週冠軍票房列表</a>
# </li>
# <li>
# <a class="gabtn" data-ga="['排行榜','排行榜_年度票房榜tab','']" href="https://movies.yahoo.com.tw/chart.html?cate=year">年度票房榜</a>
# </li>
# <li>
# <a class="gabtn" data-ga="['排行榜','排行榜_預告片榜tab','']" href="https://movies.yahoo.com.tw/chart.html?cate=trailer">預告片榜</a>
# </li>
# <li>
# <a class="gabtn" data-ga="['排行榜','排行榜_網友期待榜tab','']" href="https://movies.yahoo.com.tw/chart.html?cate=exp_30">網友期待榜</a>
# </li>
# <li>
# <a class="gabtn" data-ga="['排行榜','排行榜_網友滿意榜tab','']" href="https://movies.yahoo.com.tw/chart.html?cate=rating">網友滿意榜</a>
# </li>
# </ul>
# </div>
# <div class="rank_list_infobox">
# <div class="sharebox">
# <a class="fbicon fb_share_send" href="#"><img alt="" src="/build/images/icon_share_fb.png?r=1673238185"/></a>
# </div>
# </div>
# <div class="rank_list table rankstyle1">
# <div class="tr top">
# <div class="td">本週</div>
# <div class="td updown"></div>
# <div class="td">上週</div>
# <div class="td">片名</div>
# <div class="td">上映日期</div>
# <div class="td">預告片</div>
# <div class="td">網友滿意度</div>
# </div>
# <div class="tr">
# <div class="td">1</div>
# <div class="td up"></div>
# <div class="td">6</div>
# <div class="td">
# <a href="https://movies.yahoo.com.tw/movieinfo_main/%E7%81%8C%E7%B1%83%E9%AB%98%E6%89%8B-THE-FIRST-SLAM-DUNK-the-first-slam-dunk-14330"> <dl class="rank_list_box">
# <dt>
# <img alt="" src="https://movies.yahoo.com.tw/i/r/w420/production/movies/November2022/Ehl7e402ukfrGS1Ih7Mh-1080x1542.jpg"/>
# </dt>
# <dd>
# <h2>灌籃高手 THE FIRST SLAM DUNK</h2>
# <h3>The First Slam Dunk (ザ・ファーストスラムダンク)</h3>
# <span class="jq_text_overflow_80 jq_text_overflow_link">
#                           「教練，我想打籃球！」火紅32年的經典漫畫《灌籃高手》從1990年連載到1996年，人物角色為了籃球比賽揮灑熱血汗水激勵不少人骨子裡的「籃球魂」，光在日本的發行量就超過1億2千萬冊，在台灣也擄獲不少粉絲，櫻木花道、流川楓、宮城良田、三井壽、赤木剛憲、赤木晴子等角色都各自有擁護者；儘管連載結束26年，書迷一直引頸期盼作品能回歸，2019年當原作井上雄彥在社群公佈櫻木花道的繪圖時，關注度瞬間破表，大家紛紛留言回憶起當年追漫畫跟動畫的感動，就知道書迷有多期待。
#                         </span>
# </dd>
# </dl>
# </a> </div>
# <div class="td">2023-01-13</div>
# <div class="td icon_notice">
# </div>
# <div class="td starwithnum">
# <h6 class="count" data-num="4.5" data-run="0">4.5</h6>
# <div class="starbox starnumbox">
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# </div>
# </div>
# <!--20170531 ▲-->
# </div>
# <div class="tr">
# <div class="td">2</div>
# <div class="td down"></div>
# <div class="td">1</div>
# <div class="td">
# <a href="https://movies.yahoo.com.tw/movieinfo_main/%E9%98%BF%E5%87%A1%E9%81%94-%E6%B0%B4%E4%B9%8B%E9%81%93-avatar-the-way-of-water-13257"> <div class="rank_txt">阿凡達：水之道</div>
# </a> </div>
# <div class="td">2022-12-14</div>
# <div class="td icon_notice">
# <a href="https://movies.yahoo.com.tw/video/%E9%98%BF%E5%87%A1%E9%81%94-%E6%B0%B4%E4%B9%8B%E9%81%93-100%E7%A7%92%E6%B7%B1%E5%85%A5%E6%BD%98%E6%9C%B5%E6%8B%89%E7%A5%9E%E5%A5%87%E5%A5%A7%E7%A7%98%E4%B8%96%E7%95%8C%E7%AF%87-133920258.html">預告片</a>
# </div>
# <div class="td starwithnum">
# <h6 class="count" data-num="4.1" data-run="0">4.1</h6>
# <div class="starbox starnumbox">
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# </div>
# </div>
# <!--20170531 ▲-->
# </div>
# <div class="tr">
# <div class="td">3</div>
# <div class="td new"></div>
# <div class="td"></div>
# <div class="td">
# <a href="https://movies.yahoo.com.tw/movieinfo_main/%E7%AA%92%E5%8F%8B%E6%A2%85%E6%A0%B9-m3gan-14169"> <div class="rank_txt">窒友梅根</div>
# </a> </div>
# <div class="td">2023-01-13</div>
# <div class="td icon_notice">
# <a href="https://movies.yahoo.com.tw/video/%E7%AA%92%E5%8F%8B%E6%A2%85%E6%A0%B9-%E6%A2%85%E6%A0%B9%E7%AF%87-014052806.html">預告片</a>
# </div>
# <div class="td starwithnum">
# <h6 class="count" data-num="4.2" data-run="0">4.2</h6>
# <div class="starbox starnumbox">
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# </div>
# </div>
# <!--20170531 ▲-->
# </div>
# <div class="tr">
# <div class="td">4</div>
# <div class="td down"></div>
# <div class="td">2</div>
# <div class="td">
# <a href="https://movies.yahoo.com.tw/movieinfo_main/%E6%83%B3%E8%A6%8B%E4%BD%A0-someday-or-one-day-14528"> <div class="rank_txt">想見你</div>
# </a> </div>
# <div class="td">2022-12-30</div>
# <div class="td icon_notice">
# <a href="https://movies.yahoo.com.tw/video/%E6%83%B3%E8%A6%8B%E4%BD%A0-%E9%B3%B3%E5%8D%97%E5%B0%8F%E9%9A%8A-%E5%B0%88%E8%A8%AA-%E8%A8%B1%E5%85%89%E6%BC%A2-%E6%9F%AF%E4%BD%B3%E5%AC%BF-092820880.html">預告片</a>
# </div>
# <div class="td starwithnum">
# <h6 class="count" data-num="4.2" data-run="0">4.2</h6>
# <div class="starbox starnumbox">
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# </div>
# </div>
# <!--20170531 ▲-->
# </div>
# <div class="tr">
# <div class="td">5</div>
# <div class="td new"></div>
# <div class="td"></div>
# <div class="td">
# <a href="https://movies.yahoo.com.tw/movieinfo_main/%E6%88%91%E7%9A%84%E5%A9%86%E5%A9%86%E6%80%8E%E9%BA%BC%E6%8A%8AOO%E6%90%9E%E4%B8%9F%E4%BA%86-u-motherbaker-the-movie-14317"> <div class="rank_txt">我的婆婆怎麼把ＯＯ搞丟了</div>
# </a> </div>
# <div class="td">2023-01-13</div>
# <div class="td icon_notice">
# <a href="https://movies.yahoo.com.tw/video/%E6%88%91%E7%9A%84%E5%A9%86%E5%A9%86%E6%80%8E%E9%BA%BC%E6%8A%8Aoo%E6%90%9E%E4%B8%9F%E4%BA%86-%E7%B7%A3%E8%B5%B7%E7%AF%87%E8%8A%B1%E7%B5%AE-134554667.html">預告片</a>
# </div>
# <div class="td starwithnum">
# <h6 class="count" data-num="3.1" data-run="0">3.1</h6>
# <div class="starbox starnumbox">
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# </div>
# </div>
# <!--20170531 ▲-->
# </div>
# <div class="tr">
# <div class="td">6</div>
# <div class="td new"></div>
# <div class="td"></div>
# <div class="td">
# <a href="https://movies.yahoo.com.tw/movieinfo_main/%E5%9C%A8%E6%88%91%E5%92%8C%E5%A4%A9%E7%A9%BA%E4%B9%8B%E9%96%93-living-in-your-sky-13601"> <div class="rank_txt">山中森林</div>
# </a> </div>
# <div class="td">2022-07-15</div>
# <div class="td icon_notice">
# <a href="https://movies.yahoo.com.tw/video/%E5%9C%A8%E6%88%91%E5%92%8C%E5%A4%A9%E7%A9%BA%E4%B9%8B%E9%96%93-%E4%B8%AD%E6%96%87%E9%A0%90%E5%91%8A-074357096.html">預告片</a>
# </div>
# <div class="td starwithnum">
# <h6 class="count" data-num="2.5" data-run="0">2.5</h6>
# <div class="starbox starnumbox">
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# </div>
# </div>
# <!--20170531 ▲-->
# </div>
# <div class="tr">
# <div class="td">7</div>
# <div class="td down"></div>
# <div class="td">3</div>
# <div class="td">
# <a href="https://movies.yahoo.com.tw/movieinfo_main/%E9%9E%8B%E8%B2%93%E5%8A%8D%E5%AE%A22-puss-in-boots-the-last-wish-12816"> <div class="rank_txt">鞋貓劍客 2</div>
# </a> </div>
# <div class="td">2022-12-30</div>
# <div class="td icon_notice">
# <a href="https://movies.yahoo.com.tw/video/%E9%9E%8B%E8%B2%93%E5%8A%8D%E5%AE%A22-%E5%9B%9E%E9%A1%A7%E7%AF%87-041205727.html">預告片</a>
# </div>
# <div class="td starwithnum">
# <h6 class="count" data-num="4.5" data-run="0">4.5</h6>
# <div class="starbox starnumbox">
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# </div>
# </div>
# <!--20170531 ▲-->
# </div>
# <div class="tr">
# <div class="td">8</div>
# <div class="td down"></div>
# <div class="td">5</div>
# <div class="td">
# <a href="https://movies.yahoo.com.tw/movieinfo_main/%E8%BC%9D%E5%A4%9C%E5%A7%AC%E6%83%B3%E8%AE%93%E4%BA%BA%E5%91%8A%E7%99%BD-%E6%B0%B8%E4%B8%8D%E7%B5%90%E6%9D%9F%E7%9A%84%E5%88%9D%E5%90%BB-kaguya-sama-love-is-war-the-first-kiss-that-never-ends-14542"> <div class="rank_txt">輝夜姬想讓人告白－永不結束的初吻</div>
# </a> </div>
# <div class="td">2022-12-23</div>
# <div class="td icon_notice">
# <a href="https://movies.yahoo.com.tw/video/%E8%BC%9D%E5%A4%9C%E5%A7%AC%E6%83%B3%E8%AE%93%E4%BA%BA%E5%91%8A%E7%99%BD-%E6%B0%B8%E4%B8%8D%E7%B5%90%E6%9D%9F%E7%9A%84%E5%88%9D%E5%90%BB-%E9%95%B7%E7%89%88%E9%A0%90%E5%91%8A-121043923.html">預告片</a>
# </div>
# <div class="td starwithnum">
# <h6 class="count" data-num="4.2" data-run="0">4.2</h6>
# <div class="starbox starnumbox">
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# </div>
# </div>
# <!--20170531 ▲-->
# </div>
# <div class="tr">
# <div class="td">9</div>
# <div class="td new"></div>
# <div class="td"></div>
# <div class="td">
# <div class="rank_txt">巧虎電影　巧虎與塔魯王子</div>
# </div>
# <div class="td">未定</div>
# <div class="td icon_notice">
# </div>
# <div class="td starwithnum">
# </div>
# <!--20170531 ▲-->
# </div>
# <div class="tr">
# <div class="td">10</div>
# <div class="td new"></div>
# <div class="td"></div>
# <div class="td">
# <a href="https://movies.yahoo.com.tw/movieinfo_main/%E6%84%9B-%E5%AD%90-the-son-14054"> <div class="rank_txt">愛．子</div>
# </a> </div>
# <div class="td">2023-01-13</div>
# <div class="td icon_notice">
# <a href="https://movies.yahoo.com.tw/video/%E6%84%9B-%E5%AD%90-%E9%A6%96%E6%94%AF%E9%A0%90%E5%91%8A-025103362.html">預告片</a>
# </div>
# <div class="td starwithnum">
# <h6 class="count" data-num="3.3" data-run="0">3.3</h6>
# <div class="starbox starnumbox">
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# </div>
# </div>
# <!--20170531 ▲-->
# </div>
# <div class="tr">
# <div class="td">11</div>
# <div class="td new"></div>
# <div class="td"></div>
# <div class="td">
# <a href="https://movies.yahoo.com.tw/movieinfo_main/%E9%82%A3%E5%80%8B%E7%94%B7%E4%BA%BA-a-man-14586"> <div class="rank_txt">那個男人</div>
# </a> </div>
# <div class="td">2023-01-13</div>
# <div class="td icon_notice">
# <a href="https://movies.yahoo.com.tw/video/%E9%82%A3%E5%80%8B%E7%94%B7%E4%BA%BA-%E4%B8%AD%E6%96%87%E9%A0%90%E5%91%8A-021641762.html">預告片</a>
# </div>
# <div class="td starwithnum">
# <h6 class="count" data-num="3.7" data-run="0">3.7</h6>
# <div class="starbox starnumbox">
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# </div>
# </div>
# <!--20170531 ▲-->
# </div>
# <div class="tr">
# <div class="td">12</div>
# <div class="td down"></div>
# <div class="td">4</div>
# <div class="td">
# <a href="https://movies.yahoo.com.tw/movieinfo_main/%E5%8A%AB%E5%A9%9A%E5%A4%A7%E4%BD%9C%E6%88%B0-shotgun-wedding-14409"> <div class="rank_txt">劫婚大作戰</div>
# </a> </div>
# <div class="td">2023-01-06</div>
# <div class="td icon_notice">
# <a href="https://movies.yahoo.com.tw/video/%E5%8A%AB%E5%A9%9A%E5%A4%A7%E4%BD%9C%E6%88%B0-%E4%B8%AD%E6%96%87%E9%A0%90%E5%91%8A-161731287.html">預告片</a>
# </div>
# <div class="td starwithnum">
# <h6 class="count" data-num="4.6" data-run="0">4.6</h6>
# <div class="starbox starnumbox">
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# </div>
# </div>
# <!--20170531 ▲-->
# </div>
# <div class="tr">
# <div class="td">13</div>
# <div class="td new"></div>
# <div class="td"></div>
# <div class="td">
# <a href="https://movies.yahoo.com.tw/movieinfo_main/HERO-hero-14584"> <div class="rank_txt">HERO</div>
# </a> </div>
# <div class="td">2023-01-13</div>
# <div class="td icon_notice">
# <a href="https://movies.yahoo.com.tw/video/hero-%E4%B8%AD%E6%96%87%E9%A0%90%E5%91%8A-170553193.html">預告片</a>
# </div>
# <div class="td starwithnum">
# <h6 class="count" data-num="4.3" data-run="0">4.3</h6>
# <div class="starbox starnumbox">
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# </div>
# </div>
# <!--20170531 ▲-->
# </div>
# <div class="tr">
# <div class="td">14</div>
# <div class="td down"></div>
# <div class="td">11</div>
# <div class="td">
# <a href="https://movies.yahoo.com.tw/movieinfo_main/%E6%B5%81%E9%BA%BB%E6%BA%9D%E5%8D%81%E4%BA%94%E8%99%9F-untold-herstory-14078"> <div class="rank_txt">流麻溝十五號</div>
# </a> </div>
# <div class="td">2022-10-28</div>
# <div class="td icon_notice">
# <a href="https://movies.yahoo.com.tw/video/%E6%B5%81%E9%BA%BB%E6%BA%9D%E5%8D%81%E4%BA%94%E8%99%9F-%E4%B8%AD%E6%96%87%E9%A0%90%E5%91%8A-075607392.html">預告片</a>
# </div>
# <div class="td starwithnum">
# <h6 class="count" data-num="3.9" data-run="0">3.9</h6>
# <div class="starbox starnumbox">
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# </div>
# </div>
# <!--20170531 ▲-->
# </div>
# <div class="tr">
# <div class="td">15</div>
# <div class="td down"></div>
# <div class="td">7</div>
# <div class="td">
# <a href="https://movies.yahoo.com.tw/movieinfo_main/%E7%B4%B3%E6%8E%A2%E8%BF%BD%E7%B7%9D%E4%BB%A4-gentleman-14554"> <div class="rank_txt">紳探追緝令</div>
# </a> </div>
# <div class="td">2023-01-06</div>
# <div class="td icon_notice">
# <a href="https://movies.yahoo.com.tw/video/%E7%B4%B3%E6%8E%A2%E8%BF%BD%E7%B7%9D%E4%BB%A4-%E4%B8%AD%E6%96%87%E9%A0%90%E5%91%8A-035315732.html">預告片</a>
# </div>
# <div class="td starwithnum">
# <h6 class="count" data-num="4.7" data-run="0">4.7</h6>
# <div class="starbox starnumbox">
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# </div>
# </div>
# <!--20170531 ▲-->
# </div>
# <div class="tr">
# <div class="td">16</div>
# <div class="td new"></div>
# <div class="td"></div>
# <div class="td">
# <a href="https://movies.yahoo.com.tw/movieinfo_main/%E9%97%9C%E6%96%BC%E6%88%91%E5%92%8C%E9%AC%BC%E8%AE%8A%E6%88%90%E5%AE%B6%E4%BA%BA%E7%9A%84%E9%82%A3%E4%BB%B6%E4%BA%8B-marry-my-dead-body-14301"> <div class="rank_txt">關於我和鬼變成家人的那件事</div>
# </a> </div>
# <div class="td">2023-02-10</div>
# <div class="td icon_notice">
# <a href="https://movies.yahoo.com.tw/video/%E9%97%9C%E6%96%BC%E6%88%91%E5%92%8C%E9%AC%BC%E8%AE%8A%E6%88%90%E5%AE%B6%E4%BA%BA%E7%9A%84%E9%82%A3%E4%BB%B6%E4%BA%8B-%E6%AD%A3%E5%BC%8F%E9%A0%90%E5%91%8A-112324412.html">預告片</a>
# </div>
# <div class="td starwithnum">
# <h6 class="count" data-num="0" data-run="0">0</h6>
# <div class="starbox starnumbox">
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# </div>
# </div>
# <!--20170531 ▲-->
# </div>
# <div class="tr">
# <div class="td">17</div>
# <div class="td down"></div>
# <div class="td">9</div>
# <div class="td">
# <a href="https://movies.yahoo.com.tw/movieinfo_main/%E8%88%87%E4%BD%A0%E5%85%B1%E8%88%9E-i-wanna-dance-with-somebody-14044"> <div class="rank_txt">與你共舞</div>
# </a> </div>
# <div class="td">2022-12-30</div>
# <div class="td icon_notice">
# <a href="https://movies.yahoo.com.tw/video/%E8%88%87%E4%BD%A0%E5%85%B1%E8%88%9E-%E8%B6%85%E7%B4%9A%E7%9B%83%E5%9C%8B%E6%AD%8C%E6%BC%94%E5%94%B1%E7%89%87%E6%AE%B5-084420233.html">預告片</a>
# </div>
# <div class="td starwithnum">
# <h6 class="count" data-num="4.4" data-run="0">4.4</h6>
# <div class="starbox starnumbox">
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# </div>
# </div>
# <!--20170531 ▲-->
# </div>
# <div class="tr">
# <div class="td">18</div>
# <div class="td down"></div>
# <div class="td">13</div>
# <div class="td">
# <a href="https://movies.yahoo.com.tw/movieinfo_main/%E5%8A%87%E5%A0%B4%E7%89%88-%E5%BC%A6%E9%9F%B3-%E5%88%9D%E5%A7%8B%E7%9A%84%E4%B8%80%E5%B0%84-tsurune-the-movie-the-first-shot-14479"> <div class="rank_txt">劇場版 弦音 ─初始的一射─</div>
# </a> </div>
# <div class="td">2022-12-30</div>
# <div class="td icon_notice">
# <a href="https://movies.yahoo.com.tw/video/%E5%8A%87%E5%A0%B4%E7%89%88-%E5%BC%A6%E9%9F%B3-%E5%88%9D%E5%A7%8B%E7%9A%84-%E5%B0%84-%E4%B8%AD%E6%96%87%E9%A0%90%E5%91%8A-145553223.html">預告片</a>
# </div>
# <div class="td starwithnum">
# <h6 class="count" data-num="3.5" data-run="0">3.5</h6>
# <div class="starbox starnumbox">
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# </div>
# </div>
# <!--20170531 ▲-->
# </div>
# <div class="tr">
# <div class="td">19</div>
# <div class="td new"></div>
# <div class="td"></div>
# <div class="td">
# <a href="https://movies.yahoo.com.tw/movieinfo_main/%E8%A9%90%E5%9C%98%E5%9C%93-scamsgiving-14398"> <div class="rank_txt">詐團圓</div>
# </a> </div>
# <div class="td">2023-01-20</div>
# <div class="td icon_notice">
# <a href="https://movies.yahoo.com.tw/video/%E8%A9%90%E5%9C%98%E5%9C%93-%E5%A0%B4%E6%99%AF%E7%AF%87-131920648.html">預告片</a>
# </div>
# <div class="td starwithnum">
# <h6 class="count" data-num="3.9" data-run="0">3.9</h6>
# <div class="starbox starnumbox">
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# </div>
# </div>
# <!--20170531 ▲-->
# </div>
# <div class="tr">
# <div class="td">20</div>
# <div class="td down"></div>
# <div class="td">15</div>
# <div class="td">
# <a href="https://movies.yahoo.com.tw/movieinfo_main/%E9%96%8B%E5%BF%83%E6%BC%A2%E5%A0%A1%E5%BA%97-%E9%9B%BB%E5%BD%B1%E7%89%88-the-bobs-burgers-movie-13548"> <div class="rank_txt">五星饗魘</div>
# </a> </div>
# <div class="td">2022-07-13</div>
# <div class="td icon_notice">
# </div>
# <div class="td starwithnum">
# <h6 class="count" data-num="1.5" data-run="0">1.5</h6>
# <div class="starbox starnumbox">
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# </div>
# </div>
# <!--20170531 ▲-->
# </div>
# </div>
# <div class="rank_list_bottombtn">
# <ul>
# <li class="select"><a href="https://movies.yahoo.com.tw/chart.html">台北票房榜</a></li>
# <li><a href="https://movies.yahoo.com.tw/chart.html?cate=us">全美票房榜</a></li>
# <li><a href="https://movies.yahoo.com.tw/chart.html?cate=week">週冠軍票房列表</a></li>
# <li><a href="https://movies.yahoo.com.tw/chart.html?cate=year">年度票房榜</a></li>
# <li><a href="https://movies.yahoo.com.tw/chart.html?cate=trailer">預告片榜</a></li>
# <li><a href="https://movies.yahoo.com.tw/chart.html?cate=exp_30">網友期待榜</a></li>
# <li><a href="https://movies.yahoo.com.tw/chart.html?cate=rating">網友滿意榜</a></li>
# </ul>
# <div class="rank_time">統計時間：2023-01-14~2023-01-15</div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </main>
# <footer class="clearfix" id="footer" style="display: block;">
# <div id="loadbox">
# <a class="gabtn" data-ga="['其他連結','其他連結_服務中心','頁尾_其他連結']" href="https://tw.help.yahoo.com/kb/helpcentral" target="_blank">服務中心</a> | <a class="gabtn" data-ga="['其他連結','其他連結_隱私權','頁尾_其他連結']" href="https://policies.yahoo.com/tw/zh-hant/yahoo/privacy/index.htm" target="_blank">隱私權(更新)</a> | <a class="gabtn" data-ga="['其他連結','其他連結_建議','頁尾_其他連結']" href="https://yahoo.uservoice.com/forums/600523" target="_blank">建議</a> | <a class="gabtn" data-ga="['其他連結','其他連結_關於我們的廣告','頁尾_其他連結']" href="https://policies.yahoo.com/tw/zh-hant/yahoo/privacy/adinfo/" target="_blank">關於我們的廣告</a>
#   | <a class="gabtn" data-ga="['其他連結','其他連結_服務條款','頁尾_其他連結']" href="https://info.yahoo.com/legal/tw/yahoo/utos/zh-hant-tw/" target="_blank">服務條款(更新)</a>
#   | <a href="" target="_blank">
# </a>
#   由Yahoo奇摩電影戲劇 提供
# </div> </footer>
# </div>
# <!-- Javascript -->
# <script>
#     window.fbAsyncInit = function() {
#         FB.init({
#             appId            : 501887343352051,
#             autoLogAppEvents : true,
#             xfbml            : true,
#             version          : 'v14.0'
#         });
#         FB.AppEvents.logPageView();
#         // fb iframe 如果出現 error popup 的話會觸發focus，導致頁面被scroll至iframe的位置
#         // 目前先以外面的div加position:fixed，等fb iframe畫面render完成後，延遲2s
#         // (popup需要等iframe內的js載完才會出現)再移除position:fixed
#         FB.Event.subscribe('xfbml.render', function (response) {
#             setTimeout(()=> {
#                 $('.fb-page').removeClass('fb-position-fixed');
#             }, 2000);
#         });
#     };
#
#     function fb(d, s, id){
#         var js, fjs = d.getElementsByTagName(s)[0];
#         if (d.getElementById(id)) {return;}
#         js = d.createElement(s); js.id = id;
#         js.src = "//connect.facebook.net/en_US/sdk.js";
#         js.async = false;
#         js.defer = true;
#         fjs.parentNode.insertBefore(js, fjs);
#     };
#
#     setTimeout(() => {
#         fb(document, 'script', 'facebook-jssdk');
#     }, 5000);
#
#     function fbShareSend() {
#         var shareSendAll = document.querySelectorAll('.fb_share_send');
#         for(var i = 0; i < shareSendAll.length; i++) {
#             shareSendAll[i].onclick = function() {
#                 FB.ui({
#                     method: 'share_open_graph',
#                     action_type: 'og.likes',
#                     action_properties: JSON.stringify({
#                         object: this.getAttribute('data-href') ? this.getAttribute('data-href') : 'https://movies.yahoo.com.tw/chart.html',
#                     })
#                 }, function(response){});
#             }
#         }
#     }
#
#     fbShareSend();
# </script>
# <!-- Native Ad -->
# <script type="text/javascript">
#   const nativeAdAll = "bdd2eb9c-51e8-404a-921c-ae7090fc5fda";
#   const nativeAdOption = "";
#
#   window.native = window.native || [];
#   window.native.push(nativeAdAll);
#   if(nativeAdOption.length) {
#     window.native.push(nativeAdOption);
#   }
#   window.apiKey = "QS4CB5BPWQKCYKVVSR89";
#
#   function nativeAdsSetup(d) {
#       var script = d.createElement("script");
#       script.async = true;
#       script.src = "https://s.yimg.com/dy/ads/native.js";
#       d.body.appendChild(script);
#   };
#   setTimeout(()=> {
#     nativeAdsSetup(document)
#   }, [3000])
# </script>
# <script src="/build/js/vendor-jquery.js?id=1150e561f02aaa2a237a4f200face65d&amp;r=1673238185" type="text/javascript"></script>
# <script async="" src="/build/js/library.js?id=568bcb5712ae102dad0b3ec6a4b6b9cc&amp;r=1673238185" type="text/javascript"></script>
# <script async="" src="/build/js/global.js?id=a9a1a05ef2946d693bc57bd11a4312ed&amp;r=1673238185" type="text/javascript"></script>
# <script async="" src="/build/js/main-layout.js?id=692340a3411d575876b70ca4baa5773e&amp;r=1673238185" type="text/javascript"></script>
# <script async="" src="/build/js/app-v2.js?id=d11e69363263741233106fca7eb7723f&amp;r=1673238185" type="text/javascript"></script>
# <noscript><img alt="" height="1" src="https://sb.scorecardresearch.com/p?c1=2&amp;c2=7241469&amp;c7=https%3A%2F%2Fmovies.yahoo.com.tw%2Fchart.html&amp;c5=794026727&amp;cv=2.0&amp;cj=1" width="1"/></noscript>
# <script>
# </script>
# </body>
# </html>

# %%
datas=''
for i,tr in enumerate(soup.find_all('div','tr')[2:]):
    data=[]
    for j,td in enumerate(tr.find_all('div','td')):        
        print(td.text.strip(),end='\t')
        data.append(td.text.strip())
    datas+=' '.join(data)+'\n'    
    print()
    
print(datas)
# Out:
# 2		1	阿凡達：水之道	2022-12-14	預告片	4.1
# 3			窒友梅根	2023-01-13	預告片	4.2
# 4		2	想見你	2022-12-30	預告片	4.2
# 5			我的婆婆怎麼把ＯＯ搞丟了	2023-01-13	預告片	3.1
# 6			山中森林	2022-07-15	預告片	2.5
# 7		3	鞋貓劍客 2	2022-12-30	預告片	4.5
# 8		5	輝夜姬想讓人告白－永不結束的初吻	2022-12-23	預告片	4.2
# 9			巧虎電影　巧虎與塔魯王子	未定
# 10			愛．子	2023-01-13	預告片	3.3
# 11			那個男人	2023-01-13	預告片	3.7
# 12		4	劫婚大作戰	2023-01-06	預告片	4.6
# 13			HERO	2023-01-13	預告片	4.3
# 14		11	流麻溝十五號	2022-10-28	預告片	3.9
# 15		7	紳探追緝令	2023-01-06	預告片	4.7
# 16			關於我和鬼變成家人的那件事	2023-02-10	預告片	0
# 17		9	與你共舞	2022-12-30	預告片	4.4
# 18		13	劇場版 弦音 ─初始的一射─	2022-12-30	預告片	3.5
# 19			詐團圓	2023-01-20	預告片	3.9
# 20		15	五星饗魘	2022-07-13		1.5
# 2  1 阿凡達：水之道 2022-12-14 預告片 4.1
# 3   窒友梅根 2023-01-13 預告片 4.2
# 4  2 想見你 2022-12-30 預告片 4.2
# 5   我的婆婆怎麼把ＯＯ搞丟了 2023-01-13 預告片 3.1
# 6   山中森林 2022-07-15 預告片 2.5
# 7  3 鞋貓劍客 2 2022-12-30 預告片 4.5
# 8  5 輝夜姬想讓人告白－永不結束的初吻 2022-12-23 預告片 4.2
# 9   巧虎電影　巧虎與塔魯王子 未定
# 10   愛．子 2023-01-13 預告片 3.3
# 11   那個男人 2023-01-13 預告片 3.7
# 12  4 劫婚大作戰 2023-01-06 預告片 4.6
# 13   HERO 2023-01-13 預告片 4.3
# 14  11 流麻溝十五號 2022-10-28 預告片 3.9
# 15  7 紳探追緝令 2023-01-06 預告片 4.7
# 16   關於我和鬼變成家人的那件事 2023-02-10 預告片 0
# 17  9 與你共舞 2022-12-30 預告片 4.4
# 18  13 劇場版 弦音 ─初始的一射─ 2022-12-30 預告片 3.5
# 19   詐團圓 2023-01-20 預告片 3.9
# 20  15 五星饗魘 2022-07-13  1.5
